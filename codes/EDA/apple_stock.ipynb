# %%
import pandas as pd
import numpy as np
# For graphs
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
df=pd.read_csv('../../data/00-raw-data/AAPL.csv')

# %%
df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2022-09-28  147.639999  150.639999  144.839996  149.839996  148.956329
# 1    2022-09-29  146.100006  146.720001  140.679993  142.479996  141.639725
# 2    2022-09-30  141.279999  143.100006  138.000000  138.199997  137.384979
# 3    2022-10-03  138.210007  143.070007  137.690002  142.449997  141.609909
# 4    2022-10-04  145.029999  146.220001  144.259995  146.100006  145.238388
# ..          ...         ...         ...         ...         ...         ...
# 246  2023-09-21  174.550003  176.300003  173.860001  173.929993  173.929993
# 247  2023-09-22  174.669998  177.080002  174.050003  174.789993  174.789993
# 248  2023-09-25  174.199997  176.970001  174.149994  176.080002  176.080002
# 249  2023-09-26  174.820007  175.199997  171.660004  171.960007  171.960007
# 250  2023-09-27  172.619995  173.039993  169.050003  170.429993  170.429993
#
#         Volume
# 0    146691400
# 1    128138200
# ...

# %%
df.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
df.describe(
# Out:
#   Cell In[5], line 1
#     df.describe(
#                 ^
# SyntaxError: unexpected EOF while parsing

# %%
fig = px.line(df, x = 'Date', y = 'Open', title = 'Apple Open Price')
fig.update_xaxes(title_text = 'Date')
fig.update_yaxes(title_text = 'Open Price')
fig.update_xaxes(tickangle = 45)
fig.show()

# %%
fig = px.line(df, x = 'Date', y = 'Volume', title = 'Apple Shares Trading Volume')
fig.update_xaxes(title_text = 'Date')
fig.update_yaxes(title = 'Trading Volume')
fig.update_yaxes(tickangle = 45)
fig.show()

# %%
def detect_outliers(data):
    # Calculate Q1, Q3, and IQR
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1

    # Determine bounds for outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Identify outliers
    outliers = data[(data < lower_bound) | (data > upper_bound)]
    return outliers

outliers_stock_price = detect_outliers(df['Open'])
print(f"Number of outliers in stock price : {len(outliers_stock_price)}")
print('percentage:',len(outliers_stock_price)/len(df))
# Out:
# Number of outliers in stock price : 0
# percentage: 0.0
